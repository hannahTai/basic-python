# %% [markdown]
# <a href="https://colab.research.google.com/github/hannahTai/basic-python/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. 執行有前後順序
# 2. 設定編輯器: consolas,縮排4,顯示行數,顯示縮排

# %%
a = 3
print(a)
if a > 5:
    if a == 6:
        pass
    else:
        pass
else:
    pass
# Out:
# 3

# %%
print(a)
# Out:
# 3
